# %% [markdown]
# # [Python Reference Link](http://www.data8.org/sp20/python-reference.html)
# *Run the cell below so that we can set our modules up*

# %%
import numpy as np
from datascience import *
import math as m

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
tumor_data = Table.read_table("data.csv").drop('id','Unnamed: 32')
tumor_data
# Out:
# diagnosis | radius_mean | texture_mean | perimeter_mean | area_mean | smoothness_mean | compactness_mean | concavity_mean | concave points_mean | symmetry_mean | fractal_dimension_mean | radius_se | texture_se | perimeter_se | area_se | smoothness_se | compactness_se | concavity_se | concave points_se | symmetry_se | fractal_dimension_se | radius_worst | texture_worst | perimeter_worst | area_worst | smoothness_worst | compactness_worst | concavity_worst | concave points_worst | symmetry_worst | fractal_dimension_worst
# M         | 17.99       | 10.38        | 122.8          | 1001      | 0.1184          | 0.2776           | 0.3001         | 0.1471              | 0.2419        | 0.07871                | 1.095     | 0.9053     | 8.589        | 153.4   | 0.006399      | 0.04904        | 0.05373      | 0.01587           | 0.03003     | 0.006193             | 25.38        | 17.33         | 184.6           | 2019       | 0.1622           | 0.6656            | 0.7119          | 0.2654               | 0.4601         | 0.1189
# M         | 20.57       | 17.77        | 132.9          | 1326      | 0.08474         | 0.07864          | 0.0869         | 0.07017             | 0.1812        | 0.05667                | 0.5435    | 0.7339     | 3.398        | 74.08   | 0.005225      | 0.01308        | 0.0186       | 0.0134            | 0.01389     | 0.003532             | 24.99        | 23.41         | 158.8           | 1956       | 0.1238           | 0.1866            | 0.2416          | 0.186                | 0.275          | 0.08902
# M         | 19.69       | 21.25        | 130            | 1203      | 0.1096          | 0.1599           | 0.1974         | 0.1279              | 0.2069        | 0.05999                | 0.7456    | 0.7869     | 4.585        | 94.03   | 0.00615       | 0.04006        | 0.03832      | 0.02058           | 0.0225      | 0.004571             | 23.57        | 25.53         | 152.5           | 1709       | 0.1444           | 0.4245            | 0.4504          | 0.243                | 0.3613         | 0.08758
# M         | 11.42       | 20.38        | 77.58          | 386.1     | 0.1425          | 0.2839           | 0.2414         | 0.1052              | 0.2597        | 0.09744                | 0.4956    | 1.156      | 3.445        | 27.23   | 0.00911       | 0.07458        | 0.05661      | 0.01867           | 0.05963     | 0.009208             | 14.91        | 26.5          | 98.87           | 567.7      | 0.2098           | 0.8663            | 0.6869          | 0.2575               | 0.6638         | 0.173
# M         | 20.29       | 14.34        | 135.1          | 1297      | 0.1003          | 0.1328           | 0.198          | 0.1043              | 0.1809        | 0.05883                | 0.7572    | 0.7813     | 5.438        | 94.44   | 0.01149       | 0.02461        | 0.05688      | 0.01885           | 0.01756     | 0.005115             | 22.54        | 16.67         | 152.2           | 1575       | 0.1374           | 0.205             | 0.4             | 0.1625               | 0.2364         | 0.07678
# M         | 12.45       | 15.7         | 82.57          | 477.1     | 0.1278          | 0.17             | 0.1578         | 0.08089             | 0.2087        | 0.07613                | 0.3345    | 0.8902     | 2.217        | 27.19   | 0.00751       | 0.03345        | 0.03672      | 0.01137           | 0.02165     | 0.005082             | 15.47        | 23.75         | 103.4           | 741.6      | 0.1791           | 0.5249            | 0.5355          | 0.1741               | 0.3985         | 0.1244
# M         | 18.25       | 19.98        | 119.6          | 1040      | 0.09463         | 0.109            | 0.1127         | 0.074               | 0.1794        | 0.05742                | 0.4467    | 0.7732     | 3.18         | 53.91   | 0.004314      | 0.01382        | 0.02254      | 0.01039           | 0.01369     | 0.002179             | 22.88        | 27.66         | 153.2           | 1606       | 0.1442           | 0.2576            | 0.3784          | 0.1932               | 0.3063         | 0.08368
# M         | 13.71       | 20.83        | 90.2           | 577.9     | 0.1189          | 0.1645           | 0.09366        | 0.05985             | 0.2196        | 0.07451                | 0.5835    | 1.377      | 3.856        | 50.96   | 0.008805      | 0.03029        | 0.02488      | 0.01448           | 0.01486     | 0.005412             | 17.06        | 28.14         | 110.6           | 897        | 0.1654           | 0.3682            | 0.2678          | 0.1556               | 0.3196         | 0.1151
# M         | 13          | 21.82        | 87.5           | 519.8     | 0.1273          | 0.1932           | 0.1859         | 0.09353             | 0.235         | 0.07389                | 0.3063    | 1.002      | 2.406        | 24.32   | 0.005731      | 0.03502        | 0.03553      | 0.01226           | 0.02143     | 0.003749             | 15.49        | 30.73         | 106.2           | 739.3      | 0.1703           | 0.5401            | 0.539           | 0.206                | 0.4378         | 0.1072
# M         | 12.46       | 24.04        | 83.97          | 475.9     | 0.1186          | 0.2396           | 0.2273         | 0.08543             | 0.203         | 0.08243                | 0.2976    | 1.599      | 2.039        | 23.94   | 0.007149      | 0.07217        | 0.07743      | 0.01432           | 0.01789     | 0.01008              | 15.09        | 40.68         | 97.65           | 711.4      | 0.1853           | 1.058             | 1.105           | 0.221                | 0.4366         | 0.2075
# ... (559 rows omitted)

# %% [markdown]
# # Let's take a look at ScatterPlots

# %%
tumor_labels = list(tumor_data.labels)
tumor_attribute_list = tumor_labels[1:]
tumor_attribute_array = tumor_attribute_list

# %%
# Caution, this will crash the kernel due to the volume of outputs. 

for x in tumor_attribute_list:
    tumor_attribute_list.remove(x)
    for y in tumor_attribute_list:
        tumor_data.scatter(x,y,group='diagnosis')

# %%
# This reduces the list of attributes to examine the means only, to avoid crashing the kernel. 
tumor_labels = list(tumor_data.labels)
tumor_attribute_list_means_only = tumor_labels[1:11]
tumor_attribute_array_means_only = tumor_attribute_list_means_only

# %%
# This reduces the list of attributes to examine the means only, to avoid crashing the kernel. 
for x in tumor_attribute_list_means_only:
    tumor_attribute_list_means_only.remove(x)
    for y in tumor_attribute_list_means_only:
        tumor_data.scatter(x,y,group='diagnosis')
# Out:
# /opt/conda/lib/python3.10/site-packages/datascience/tables.py:4700: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(n, 1, figsize=(width, height*n))

# %% [markdown]
# # Steps covered in (11/28) lecture, now defined as functions

# %%
# The function below will take a table, and a number as inputs. 
# Then the function will randomly shuffle the rows of the table and take the input number of rows for the training set. 
# The remaining rows will be stored as the test set. 
# The function returns both the training set and the test set. 

def train_test_separation(tbl,num_for_train):
    shuffled_tbl = tbl.sample(with_replacement = False)
    
    train_tbl = shuffled_tbl.take(np.arange(num_for_train))
    test_tbl = shuffled_tbl.take(np.arange(num_for_train,tbl.num_rows))
    
    print("Training set:\t",   train_tbl.num_rows, "examples")
    print("Test set:\t",       test_tbl.num_rows, "examples")
    
    return train_tbl, test_tbl

# The function below will take in two arrays of numbers as inputs. 
# It will then compute the Euclidean distance between the those two arrays as an output. 

def distance(array_one,array_two):
    return (sum((array_one - array_two)**2))**(0.5)

# %% [markdown]
# #### The following function below is defined for you homework 12

# %%
# row (input): a row from the table 
# features (input): an array of column labels. These labels are the attributes that will help us classify individuals. 
# Note: the attributes must be numerical to help us pass them through the distance function defined above. 

def row_to_array(row, features):
    """Converts a row to an array of its features."""
    arr = make_array()
    for feature in features:
        arr = np.append(arr, row.item(feature))
    return arr

# %% [markdown]
# # Let's classify these tumor cells

# %% [markdown]
# ## Finding the `k` Nearest Neighbors

# %% [markdown]
# ### Some pre-formatting:

# %%
train, test = train_test_separation(tumor_data,450)
# Out:
# Training set:	 450 examples
# Test set:	 119 examples

# %%
row_to_test = test.row(0)
row_to_test
# Out:
# Row(diagnosis='B', radius_mean=13.65, texture_mean=13.16, perimeter_mean=87.879999999999995, area_mean=568.89999999999998, smoothness_mean=0.096460000000000004, compactness_mean=0.087110000000000007, concavity_mean=0.038879999999999998, concave points_mean=0.02563, symmetry_mean=0.13600000000000001, fractal_dimension_mean=0.063439999999999996, radius_se=0.2102, texture_se=0.43359999999999999, perimeter_se=1.391, area_se=17.399999999999999, smoothness_se=0.0041330000000000004, compactness_se=0.01695, concavity_se=0.01652, concave points_se=0.006659, symmetry_se=0.01371, fractal_dimension_se=0.002735, radius_worst=15.34, texture_worst=16.350000000000001, perimeter_worst=99.709999999999994, area_worst=706.20000000000005, smoothness_worst=0.13109999999999999, compactness_worst=0.24740000000000001, concavity_worst=0.1759, concave points_worst=0.080560000000000007, symmetry_worst=0.23799999999999999, fractal_dimension_worst=0.087179999999999994)

# %%
test_features_array = row_to_array(row_to_test,tumor_attribute_array)
test_features_array
# Out:
# array([  1.36500000e+01,   1.31600000e+01,   8.78800000e+01,
#          5.68900000e+02,   9.64600000e-02,   8.71100000e-02,
#          3.88800000e-02,   2.56300000e-02,   1.36000000e-01,
#          6.34400000e-02,   2.10200000e-01,   4.33600000e-01,
#          1.39100000e+00,   1.74000000e+01,   4.13300000e-03,
#          1.69500000e-02,   1.65200000e-02,   6.65900000e-03,
#          1.37100000e-02,   2.73500000e-03,   1.53400000e+01,
#          1.63500000e+01,   9.97100000e+01,   7.06200000e+02,
#          1.31100000e-01,   2.47400000e-01,   1.75900000e-01,
#          8.05600000e-02,   2.38000000e-01,   8.71800000e-02])

# %% [markdown]
# ### Find the distance between the example (i.e. test row) and each example in the training set

# %%
# we will store the distance between the test row with all the rows in the training set. 
distances = make_array()

# we will iterate through the training set row by row.  
for train_row in train.rows:
    #convert the train_row into an array also
    train_row_array = row_to_array(train_row,tumor_attribute_array)
    # compute the distance between the test row array and test row array
    train_distance = distance(train_row_array, test_features_array)
    # save the distance between these two arrays (test row and train row) into the distances array
    distances = np.append(distances, train_distance)
    

distances
# Out:
# array([  242.71677068,   401.17630976,   290.03320568,   336.71583024,
#          102.76331902,   905.64662249,   163.06194472,   361.95769148,
#          501.11754661,   184.18965034,  1194.36385677,   186.66701258,
#          190.66015028,   522.76475198,   481.96445105,   132.87780669,
#          233.14249002,   184.97297947,   325.92856531,   429.85653882,
#          308.96453221,  1781.10456875,   492.67188944,   154.3408669 ,
#          260.04690593,   196.20740523,  1187.05500952,   212.70595082,
#          146.79191181,    29.50064405,    25.41965368,   256.57204757,
#          605.41460614,    68.49181666,   209.17193682,   240.51309276,
#          341.69962162,   110.92103818,    24.80944368,   693.96605586,
#          589.42408339,   415.15938698,   181.29498237,   103.98370268,
#          300.60636784,   254.58208469])

# %% [markdown]
# ### Augment the training data table with a column containing all the distances

# %%
train_with_distances = train.with_column('distances',distances)

# %%
train_with_distances
# Out:
# diagnosis | radius_mean | texture_mean | perimeter_mean | area_mean | smoothness_mean | compactness_mean | concavity_mean | concave points_mean | symmetry_mean | fractal_dimension_mean | radius_se | texture_se | perimeter_se | area_se | smoothness_se | compactness_se | concavity_se | concave points_se | symmetry_se | fractal_dimension_se | radius_worst | texture_worst | perimeter_worst | area_worst | smoothness_worst | compactness_worst | concavity_worst | concave points_worst | symmetry_worst | fractal_dimension_worst | distances
# B         | 12.18       | 17.84        | 77.79          | 451.1     | 0.1045          | 0.07057          | 0.0249         | 0.02941             | 0.19          | 0.06635                | 0.3661    | 1.511      | 2.41         | 24.44   | 0.005433      | 0.01179        | 0.01131      | 0.01519           | 0.0222      | 0.003408             | 12.83        | 20.92         | 82.14           | 495.2      | 0.114            | 0.09358           | 0.0498          | 0.05882              | 0.2227         | 0.07376                 | 242.717
# B         | 10.25       | 16.18        | 66.52          | 324.2     | 0.1061          | 0.1111           | 0.06726        | 0.03965             | 0.1743        | 0.07279                | 0.3677    | 1.471      | 1.597        | 22.68   | 0.01049       | 0.04265        | 0.04004      | 0.01544           | 0.02719     | 0.007596             | 11.28        | 20.61         | 71.53           | 390.4      | 0.1402           | 0.236             | 0.1898          | 0.09744              | 0.2608         | 0.09702                 | 401.176
# B         | 11.34       | 18.61        | 72.76          | 391.2     | 0.1049          | 0.08499          | 0.04302        | 0.02594             | 0.1927        | 0.06211                | 0.243     | 1.01       | 1.491        | 18.19   | 0.008577      | 0.01641        | 0.02099      | 0.01107           | 0.02434     | 0.001217             | 12.47        | 23.03         | 79.15           | 478.6      | 0.1483           | 0.1574            | 0.1624          | 0.08542              | 0.306          | 0.06783                 | 290.033
# B         | 10.65       | 25.22        | 68.01          | 347       | 0.09657         | 0.07234          | 0.02379        | 0.01615             | 0.1897        | 0.06329                | 0.2497    | 1.493      | 1.497        | 16.64   | 0.007189      | 0.01035        | 0.01081      | 0.006245          | 0.02158     | 0.002619             | 12.25        | 35.19         | 77.98           | 455.7      | 0.1499           | 0.1398            | 0.1125          | 0.06136              | 0.3409         | 0.08147                 | 336.716
# B         | 13.53       | 10.94        | 87.91          | 559.2     | 0.1291          | 0.1047           | 0.06877        | 0.06556             | 0.2403        | 0.06641                | 0.4101    | 1.014      | 2.652        | 32.65   | 0.0134        | 0.02839        | 0.01162      | 0.008239          | 0.02572     | 0.006164             | 14.08        | 12.49         | 91.36           | 605.5      | 0.1451           | 0.1379            | 0.08539         | 0.07407              | 0.271          | 0.07191                 | 102.763
# M         | 18.22       | 18.87        | 118.7          | 1027      | 0.09746         | 0.1117           | 0.113          | 0.0795              | 0.1807        | 0.05664                | 0.4041    | 0.5503     | 2.547        | 48.9    | 0.004821      | 0.01659        | 0.02408      | 0.01143           | 0.01275     | 0.002451             | 21.84        | 25            | 140.9           | 1485       | 0.1434           | 0.2763            | 0.3853          | 0.1776               | 0.2812         | 0.08198                 | 905.647
# B         | 14.8        | 17.66        | 95.88          | 674.8     | 0.09179         | 0.0889           | 0.04069        | 0.0226              | 0.1893        | 0.05886                | 0.2204    | 0.6221     | 1.482        | 19.75   | 0.004796      | 0.01171        | 0.01758      | 0.006897          | 0.02254     | 0.001971             | 16.43        | 22.74         | 105.9           | 829.5      | 0.1226           | 0.1881            | 0.206           | 0.08308              | 0.36           | 0.07285                 | 163.062
# B         | 10.86       | 21.48        | 68.51          | 360.5     | 0.07431         | 0.04227          | 0              | 0                   | 0.1661        | 0.05948                | 0.3163    | 1.304      | 2.115        | 20.67   | 0.009579      | 0.01104        | 0            | 0                 | 0.03004     | 0.002228             | 11.66        | 24.77         | 74.08           | 412.3      | 0.1001           | 0.07348           | 0               | 0                    | 0.2458         | 0.06592                 | 361.958
# M         | 16.02       | 23.24        | 102.7          | 797.8     | 0.08206         | 0.06669          | 0.03299        | 0.03323             | 0.1528        | 0.05697                | 0.3795    | 1.187      | 2.466        | 40.51   | 0.004029      | 0.009269       | 0.01101      | 0.007591          | 0.0146      | 0.003042             | 19.19        | 33.88         | 123.8           | 1150       | 0.1181           | 0.1551            | 0.1459          | 0.09975              | 0.2948         | 0.08452                 | 501.118
# B         | 12.46       | 19.89        | 80.43          | 471.3     | 0.08451         | 0.1014           | 0.0683         | 0.03099             | 0.1781        | 0.06249                | 0.3642    | 1.04       | 2.579        | 28.32   | 0.00653       | 0.03369        | 0.04712      | 0.01403           | 0.0274      | 0.004651             | 13.46        | 23.07         | 88.13           | 551.3      | 0.105            | 0.2158            | 0.1904          | 0.07625              | 0.2685         | 0.07764                 | 184.19
# ... (440 rows omitted)

# %% [markdown]
# ### Sort the augmented table in increasing order of the distances

# %%
sorted_training = train_with_distances.sort('distances')

# %%
sorted_training
# Out:
# diagnosis | radius_mean | texture_mean | perimeter_mean | area_mean | smoothness_mean | compactness_mean | concavity_mean | concave points_mean | symmetry_mean | fractal_dimension_mean | radius_se | texture_se | perimeter_se | area_se | smoothness_se | compactness_se | concavity_se | concave points_se | symmetry_se | fractal_dimension_se | radius_worst | texture_worst | perimeter_worst | area_worst | smoothness_worst | compactness_worst | concavity_worst | concave points_worst | symmetry_worst | fractal_dimension_worst | distances
# B         | 13.54       | 14.36        | 87.46          | 566.3     | 0.09779         | 0.08129          | 0.06664        | 0.04781             | 0.1885        | 0.05766                | 0.2699    | 0.7886     | 2.058        | 23.56   | 0.008462      | 0.0146         | 0.02387      | 0.01315           | 0.0198      | 0.0023               | 15.11        | 19.26         | 99.7            | 711.2      | 0.144            | 0.1773            | 0.239           | 0.1288               | 0.2977         | 0.07259                 | 8.96934
# B         | 13.27       | 17.02        | 84.55          | 546.4     | 0.08445         | 0.04994          | 0.03554        | 0.02456             | 0.1496        | 0.05674                | 0.2927    | 0.8907     | 2.044        | 24.68   | 0.006032      | 0.01104        | 0.02259      | 0.009057          | 0.01482     | 0.002496             | 15.14        | 23.6          | 98.84           | 708.8      | 0.1276           | 0.1311            | 0.1786          | 0.09678              | 0.2506         | 0.07623                 | 25.4197
# B         | 13.64       | 15.6         | 87.38          | 575.3     | 0.09423         | 0.0663           | 0.04705        | 0.03731             | 0.1717        | 0.0566                 | 0.3242    | 0.6612     | 1.996        | 27.19   | 0.00647       | 0.01248        | 0.0181       | 0.01103           | 0.01898     | 0.001794             | 14.85        | 19.05         | 94.11           | 683.4      | 0.1278           | 0.1291            | 0.1533          | 0.09222              | 0.253          | 0.0651                  | 26.4988
# ... (440 rows omitted)

# %% [markdown]
# ### Take the top `k` rows of the sorted table

# %%
k = 23
top_k_training = sorted_training.take(np.arange(k))

# %%
top_k_training
# Out:
# diagnosis | radius_mean | texture_mean | perimeter_mean | area_mean | smoothness_mean | compactness_mean | concavity_mean | concave points_mean | symmetry_mean | fractal_dimension_mean | radius_se | texture_se | perimeter_se | area_se | smoothness_se | compactness_se | concavity_se | concave points_se | symmetry_se | fractal_dimension_se | radius_worst | texture_worst | perimeter_worst | area_worst | smoothness_worst | compactness_worst | concavity_worst | concave points_worst | symmetry_worst | fractal_dimension_worst | distances
# B         | 13.54       | 14.36        | 87.46          | 566.3     | 0.09779         | 0.08129          | 0.06664        | 0.04781             | 0.1885        | 0.05766                | 0.2699    | 0.7886     | 2.058        | 23.56   | 0.008462      | 0.0146         | 0.02387      | 0.01315           | 0.0198      | 0.0023               | 15.11        | 19.26         | 99.7            | 711.2      | 0.144            | 0.1773            | 0.239           | 0.1288               | 0.2977         | 0.07259                 | 8.96934
# B         | 13.5        | 12.71        | 85.69          | 566.2     | 0.07376         | 0.03614          | 0.002758       | 0.004419            | 0.1365        | 0.05335                | 0.2244    | 0.6864     | 1.509        | 20.39   | 0.003338      | 0.003746       | 0.00203      | 0.003242          | 0.0148      | 0.001566             | 14.97        | 16.94         | 95.48           | 698.7      | 0.09023          | 0.05836           | 0.01379         | 0.0221               | 0.2267         | 0.06192                 | 9.79951
# B         | 13.71       | 18.68        | 88.73          | 571       | 0.09916         | 0.107            | 0.05385        | 0.03783             | 0.1714        | 0.06843                | 0.3191    | 1.249      | 2.284        | 26.45   | 0.006739      | 0.02251        | 0.02086      | 0.01352           | 0.0187      | 0.003747             | 15.11        | 25.63         | 99.43           | 701.9      | 0.1425           | 0.2566            | 0.1935          | 0.1284               | 0.2849         | 0.09031                 | 14.9576
# B         | 13.78       | 15.79        | 88.37          | 585.9     | 0.08817         | 0.06718          | 0.01055        | 0.009937            | 0.1405        | 0.05848                | 0.3563    | 0.4833     | 2.235        | 29.34   | 0.006432      | 0.01156        | 0.007741     | 0.005657          | 0.01227     | 0.002564             | 15.27        | 17.5          | 97.9            | 706.6      | 0.1072           | 0.1071            | 0.03517         | 0.03312              | 0.1859         | 0.0681                  | 21.0781
# B         | 13.56       | 13.9         | 88.59          | 561.3     | 0.1051          | 0.1192           | 0.0786         | 0.04451             | 0.1962        | 0.06303                | 0.2569    | 0.4981     | 2.011        | 21.03   | 0.005851      | 0.02314        | 0.02544      | 0.00836           | 0.01842     | 0.002918             | 14.98        | 17.13         | 101.1           | 686.6      | 0.1376           | 0.2698            | 0.2577          | 0.0909               | 0.3065         | 0.08177                 | 21.4298
# B         | 13.7        | 17.64        | 87.76          | 571.1     | 0.0995          | 0.07957          | 0.04548        | 0.0316              | 0.1732        | 0.06088                | 0.2431    | 0.9462     | 1.564        | 20.64   | 0.003245      | 0.008186       | 0.01698      | 0.009233          | 0.01285     | 0.001524             | 14.96        | 23.53         | 95.78           | 686.5      | 0.1199           | 0.1346            | 0.1742          | 0.09077              | 0.2518         | 0.0696                  | 22.1577
# M         | 13.73       | 22.61        | 93.6           | 578.3     | 0.1131          | 0.2293           | 0.2128         | 0.08025             | 0.2069        | 0.07682                | 0.2121    | 1.169      | 2.061        | 19.21   | 0.006429      | 0.05936        | 0.05501      | 0.01628           | 0.01961     | 0.008093             | 15.03        | 32.01         | 108.8           | 697.7      | 0.1651           | 0.7725            | 0.6943          | 0.2208               | 0.3596         | 0.1431                  | 24.8094
# B         | 13.46       | 18.75        | 87.44          | 551.1     | 0.1075          | 0.1138           | 0.04201        | 0.03152             | 0.1723        | 0.06317                | 0.1998    | 0.6068     | 1.443        | 16.07   | 0.004413      | 0.01443        | 0.01509      | 0.007369          | 0.01354     | 0.001787             | 15.35        | 25.16         | 101.9           | 719.8      | 0.1624           | 0.3124            | 0.2654          | 0.1427               | 0.3518         | 0.08665                 | 24.85
# B         | 13.27       | 17.02        | 84.55          | 546.4     | 0.08445         | 0.04994          | 0.03554        | 0.02456             | 0.1496        | 0.05674                | 0.2927    | 0.8907     | 2.044        | 24.68   | 0.006032      | 0.01104        | 0.02259      | 0.009057          | 0.01482     | 0.002496             | 15.14        | 23.6          | 98.84           | 708.8      | 0.1276           | 0.1311            | 0.1786          | 0.09678              | 0.2506         | 0.07623                 | 25.4197
# B         | 13.64       | 15.6         | 87.38          | 575.3     | 0.09423         | 0.0663           | 0.04705        | 0.03731             | 0.1717        | 0.0566                 | 0.3242    | 0.6612     | 1.996        | 27.19   | 0.00647       | 0.01248        | 0.0181       | 0.01103           | 0.01898     | 0.001794             | 14.85        | 19.05         | 94.11           | 683.4      | 0.1278           | 0.1291            | 0.1533          | 0.09222              | 0.253          | 0.0651                  | 26.4988
# ... (13 rows omitted)

# %% [markdown]
# ## The Classifier

# %% [markdown]
# ### Take a majority vote of the `k` nearest neighbors to see which of the two classes appear most often (visually)

# %%
test.row(0)
# Out:
# Row(diagnosis='B', radius_mean=13.65, texture_mean=13.16, perimeter_mean=87.879999999999995, area_mean=568.89999999999998, smoothness_mean=0.096460000000000004, compactness_mean=0.087110000000000007, concavity_mean=0.038879999999999998, concave points_mean=0.02563, symmetry_mean=0.13600000000000001, fractal_dimension_mean=0.063439999999999996, radius_se=0.2102, texture_se=0.43359999999999999, perimeter_se=1.391, area_se=17.399999999999999, smoothness_se=0.0041330000000000004, compactness_se=0.01695, concavity_se=0.01652, concave points_se=0.006659, symmetry_se=0.01371, fractal_dimension_se=0.002735, radius_worst=15.34, texture_worst=16.350000000000001, perimeter_worst=99.709999999999994, area_worst=706.20000000000005, smoothness_worst=0.13109999999999999, compactness_worst=0.24740000000000001, concavity_worst=0.1759, concave points_worst=0.080560000000000007, symmetry_worst=0.23799999999999999, fractal_dimension_worst=0.087179999999999994)

# %%
top_k_training.scatter('radius_mean','texture_mean',group = 'diagnosis')

# %% [markdown]
# ### Take a majority vote of the `k` nearest neighbors to see which of the two classes appear most often (algorithm)

# %%
top_k_training.group('diagnosis').sort('count',descending = True).column('diagnosis').item(0)
# Out:
# 'B'

# %% [markdown]
# # Evaluating your classifier (Accuracy)

# %%
test
# Out:
# diagnosis | radius_mean | texture_mean | perimeter_mean | area_mean | smoothness_mean | compactness_mean | concavity_mean | concave points_mean | symmetry_mean | fractal_dimension_mean | radius_se | texture_se | perimeter_se | area_se | smoothness_se | compactness_se | concavity_se | concave points_se | symmetry_se | fractal_dimension_se | radius_worst | texture_worst | perimeter_worst | area_worst | smoothness_worst | compactness_worst | concavity_worst | concave points_worst | symmetry_worst | fractal_dimension_worst
# B         | 13.65       | 13.16        | 87.88          | 568.9     | 0.09646         | 0.08711          | 0.03888        | 0.02563             | 0.136         | 0.06344                | 0.2102    | 0.4336     | 1.391        | 17.4    | 0.004133      | 0.01695        | 0.01652      | 0.006659          | 0.01371     | 0.002735             | 15.34        | 16.35         | 99.71           | 706.2      | 0.1311           | 0.2474            | 0.1759          | 0.08056              | 0.238          | 0.08718
# B         | 13.45       | 18.3         | 86.6           | 555.1     | 0.1022          | 0.08165          | 0.03974        | 0.0278              | 0.1638        | 0.0571                 | 0.295     | 1.373      | 2.099        | 25.22   | 0.005884      | 0.01491        | 0.01872      | 0.009366          | 0.01884     | 0.001817             | 15.1         | 25.94         | 97.59           | 699.4      | 0.1339           | 0.1751            | 0.1381          | 0.07911              | 0.2678         | 0.06603
# M         | 20.64       | 17.35        | 134.8          | 1335      | 0.09446         | 0.1076           | 0.1527         | 0.08941             | 0.1571        | 0.05478                | 0.6137    | 0.6575     | 4.119        | 77.02   | 0.006211      | 0.01895        | 0.02681      | 0.01232           | 0.01276     | 0.001711             | 25.37        | 23.17         | 166.8           | 1946       | 0.1562           | 0.3055            | 0.4159          | 0.2112               | 0.2689         | 0.07055
# M         | 20.73       | 31.12        | 135.7          | 1419      | 0.09469         | 0.1143           | 0.1367         | 0.08646             | 0.1769        | 0.05674                | 1.172     | 1.617      | 7.749        | 199.7   | 0.004551      | 0.01478        | 0.02143      | 0.00928           | 0.01367     | 0.002299             | 32.49        | 47.16         | 214             | 3432       | 0.1401           | 0.2644            | 0.3442          | 0.1659               | 0.2868         | 0.08218
# B         | 12.42       | 15.04        | 78.61          | 476.5     | 0.07926         | 0.03393          | 0.01053        | 0.01108             | 0.1546        | 0.05754                | 0.1153    | 0.6745     | 0.757        | 9.006   | 0.003265      | 0.00493        | 0.006493     | 0.003762          | 0.0172      | 0.00136              | 13.2         | 20.37         | 83.85           | 543.4      | 0.1037           | 0.07776           | 0.06243         | 0.04052              | 0.2901         | 0.06783
# M         | 19.73       | 19.82        | 130.7          | 1206      | 0.1062          | 0.1849           | 0.2417         | 0.0974              | 0.1733        | 0.06697                | 0.7661    | 0.78       | 4.115        | 92.81   | 0.008482      | 0.05057        | 0.068        | 0.01971           | 0.01467     | 0.007259             | 25.28        | 25.59         | 159.8           | 1933       | 0.171            | 0.5955            | 0.8489          | 0.2507               | 0.2749         | 0.1297
# B         | 11.36       | 17.57        | 72.49          | 399.8     | 0.08858         | 0.05313          | 0.02783        | 0.021               | 0.1601        | 0.05913                | 0.1916    | 1.555      | 1.359        | 13.66   | 0.005391      | 0.009947       | 0.01163      | 0.005872          | 0.01341     | 0.001659             | 13.05        | 36.32         | 85.07           | 521.3      | 0.1453           | 0.1622            | 0.1811          | 0.08698              | 0.2973         | 0.07745
# B         | 10.8        | 9.71         | 68.77          | 357.6     | 0.09594         | 0.05736          | 0.02531        | 0.01698             | 0.1381        | 0.064                  | 0.1728    | 0.4064     | 1.126        | 11.48   | 0.007809      | 0.009816       | 0.01099      | 0.005344          | 0.01254     | 0.00212              | 11.6         | 12.02         | 73.66           | 414        | 0.1436           | 0.1257            | 0.1047          | 0.04603              | 0.209          | 0.07699
# M         | 19.18       | 22.49        | 127.5          | 1148      | 0.08523         | 0.1428           | 0.1114         | 0.06772             | 0.1767        | 0.05529                | 0.4357    | 1.073      | 3.833        | 54.22   | 0.005524      | 0.03698        | 0.02706      | 0.01221           | 0.01415     | 0.003397             | 23.36        | 32.06         | 166.4           | 1688       | 0.1322           | 0.5601            | 0.3865          | 0.1708               | 0.3193         | 0.09221
# B         | 13.85       | 19.6         | 88.68          | 592.6     | 0.08684         | 0.0633           | 0.01342        | 0.02293             | 0.1555        | 0.05673                | 0.3419    | 1.678      | 2.331        | 29.63   | 0.005836      | 0.01095        | 0.005812     | 0.007039          | 0.02014     | 0.002326             | 15.63        | 28.01         | 100.9           | 749.1      | 0.1118           | 0.1141            | 0.04753         | 0.0589               | 0.2513         | 0.06911
# ... (109 rows omitted)

# %%
diagnoses = make_array()

for test_row in test.rows: 
    test_row_array =  row_to_array(test_row,tumor_attribute_array)
    #print(test_row_array)
    distances = make_array()
#####    
    for train_row in train.rows:
        #convert the train_row into an array also
        train_row_array = row_to_array(train_row,tumor_attribute_array)
        # compute the distance between the test row array and test row array
        train_distance = distance(train_row_array, test_row_array)
        # save the distance between these two arrays (test row and train row) into the distances array
        distances = np.append(distances, train_distance)
######    
    train_with_distances = train_with_distances.with_column('distances',distances)
    sorted_training = train_with_distances.sort('distances')
    top_k_training = sorted_training.take(np.arange(k))
    diagnosis = top_k_training.group('diagnosis').sort('count',descending = True).column('diagnosis').item(0)
    diagnoses = np.append(diagnoses,diagnosis)

len(diagnoses)
# Out:
# 119

# %%
diagnoses
# Out:
# array(['B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B'],
#       dtype='<U32')

# %%
np.count_nonzero(test.column('diagnosis') == diagnoses)/len(diagnoses)
# Out:
# 0.9747899159663865

# %%
test.select('diagnosis').with_column('predicted diagnosis',diagnoses)
# Out:
# diagnosis | predicted diagnosis
# B         | B
# B         | B
# M         | M
# M         | M
# B         | B
# M         | M
# B         | B
# B         | B
# M         | M
# B         | B
# ... (109 rows omitted)
